# %%
import os
import geopandas as gpd
import ee
import geemap
import numpy as np
from concurrent.futures import ThreadPoolExecutor
from multiprocessing import cpu_count
from shapely.geometry import box

# %%
class ImageryCollector:
    def __init__(self, base_path, output_dir, segment_type, buffer_sizes, cloud_cover_threshold=20):
        self.base_path = base_path
        self.output_dir = output_dir
        self.segment_type = segment_type
        self.buffer_sizes = buffer_sizes
        self.cloud_cover_threshold = cloud_cover_threshold

    def load_segments(self, gpkg_file):
        """Load and validate the road segments data"""
        df = gpd.read_file(gpkg_file)
        if df.crs is None:
            print("Warning: Input data has no CRS specified. Assuming UTM.")
            df.set_crs(epsg=32619, inplace=True)
        df = df.to_crs(epsg=4326)
        print(f"Loaded {len(df)} segment-year combinations")
        return df

    def create_buffers(self, geometry, sizes):
        """Create buffers in UTM projection for accurate distances"""
        geom_utm = gpd.GeoSeries([geometry], crs=4326).to_crs(32619)
        buffers = {}
        for size in sizes:
            buffer_utm = geom_utm.buffer(size)
            buffer_wgs84 = buffer_utm.to_crs(4326)
            buffers[f'{size}m'] = buffer_wgs84[0]
        return buffers

    def get_landsat_collection(self, year):
        """Retrieve Landsat image collection for fall season"""
        start_date = f'{year}-09-01'
        end_date = f'{year}-10-30'

        if year < 2012:  # Landsat 5
            collection = ee.ImageCollection('LANDSAT/LT05/C02/T1_L2')
        elif year < 2014:  # Landsat 7
            collection = ee.ImageCollection('LANDSAT/LE07/C02/T1_L2')
        else:  # Landsat 8
            collection = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')

        # Filter by date and cloud cover
        collection = collection.filterDate(start_date, end_date).filter(ee.Filter.lt('CLOUD_COVER', self.cloud_cover_threshold))
        return collection

    def process_segment(self, segment_row):
        """Process a single segment"""
        try:
            segment_base_dir = os.path.join(
                self.output_dir,
                f"First 6000 segments ({self.segment_type} aggregation)",
                f"segment_{segment_row[f'{self.segment_type}_segment_id']}_{segment_row['Year']}"
            )
            os.makedirs(segment_base_dir, exist_ok=True)

            # Create buffers for the segment
            buffers = self.create_buffers(segment_row.geometry, self.buffer_sizes)

            for buffer_size in self.buffer_sizes:
                buffer_dir = os.path.join(segment_base_dir, f"{buffer_size}m")
                os.makedirs(buffer_dir, exist_ok=True)

                buffer_geom = buffers[f'{buffer_size}m']
                ee_geometry = ee.Geometry.Polygon(
                    [[[x, y] for x, y in buffer_geom.exterior.coords]]
                )

                # Get Landsat collection
                collection = self.get_landsat_collection(segment_row['Year'])
                image = collection.filterBounds(ee_geometry).sort('CLOUD_COVER').first()

                if image:
                    # Apply sensor-specific scaling
                    if segment_row['Year'] >= 2014:  # Landsat 8
                        scaled_image = image.select(['SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B6', 'SR_B7']).multiply(0.0000275).add(-0.2)
                    else:  # Landsat 5/7
                        scaled_image = image.select(['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7']).multiply(0.0001)

                    output_filename = "landsat.tif"
                    geemap.ee_export_image(
                        scaled_image,
                        filename=os.path.join(buffer_dir, output_filename),
                        scale=10,
                        region=ee_geometry,
                        crs='EPSG:4326'
                    )
                    print(f"Downloaded image for segment {segment_row[f'{self.segment_type}_segment_id']}, {buffer_size}m buffer")

        except Exception as e:
            print(f"Error processing segment {segment_row[f'{self.segment_type}_segment_id']}: {str(e)}")

    def run_collection(self, gpkg_file):
        """Run the collection process with parallel execution"""
        segments = self.load_segments(gpkg_file)

        with ThreadPoolExecutor(max_workers=cpu_count()) as executor:
            list(executor.map(self.process_segment, [row for _, row in segments.iterrows()]))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Execute Imagery Collection

def run_imagery_collection():
    # Initialize Earth Engine
    try:
        ee.Initialize()
    except Exception as e:
        print("Please run ee.Authenticate() first if you haven't already")
        raise e

    # Base configuration
    base_dir = "C:\\Users\\gmoor\\Documents\\REVISED CAPSTONE PROJECT\\Data"

    # Configuration for 100m segments
    config_100m = {
        'gpkg_file': os.path.join(base_dir, "first200_aggregate_segments (100meters).gpkg"),
        'output_base_dir': base_dir,
        'segment_type': '100m',
        'buffer_sizes': [100, 200, 300]
    }

    # Create collector instance for 100m segments
    collector_100m = ImageryCollector(
        base_path=None,
        output_dir=config_100m['output_base_dir'],
        segment_type=config_100m['segment_type'],
        buffer_sizes=config_100m['buffer_sizes']
    )

    # Load segments and process them
    segments_100m = collector_100m.load_segments(config_100m['gpkg_file'])
    print(f"\nProcessing {len(segments_100m)} segments for 100m configuration...")
    
    # Process each segment
    for _, segment in segments_100m.iterrows():
        collector_100m.process_segment(segment)

    # Configuration for 200m segments
    config_200m = {
        'gpkg_file': os.path.join(base_dir, "first200_aggregate_segments (200meters).gpkg"),
        'output_base_dir': base_dir,
        'segment_type': '200m',
        'buffer_sizes': [200, 300, 400]
    }

    # Create collector instance for 200m segments
    collector_200m = ImageryCollector(
        base_path=None,
        output_dir=config_200m['output_base_dir'],
        segment_type=config_200m['segment_type'],
        buffer_sizes=config_200m['buffer_sizes']
    )

    # Load segments and process them
    segments_200m = collector_200m.load_segments(config_200m['gpkg_file'])
    print(f"\nProcessing {len(segments_200m)} segments for 200m configuration...")
    
    # Process each segment
    for _, segment in segments_200m.iterrows():
        collector_200m.process_segment(segment)

if __name__ == "__main__":
    run_imagery_collection()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Loaded 736 segment-year combinations
#
# Processing 736 segments for 100m configuration...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/bbabb411fd41eef987165becf8f92421-d50ff9331f4323ed64b26b5976cf4941:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2007\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/8bb105f92a0734a33342ccd6c6c2f06a-958123cbd1f387585d3af6ee62396d67:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2007\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/86e5f8dce63d72eed94c60192869d34e-013e954a55ef63afa7a6cc20faec5310:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2007\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/3e6cf35cd7c77fc89685a2802a87297e-86245edeaa7e60170c188e3966075d20:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2008\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/ab60bc8268e9e0618f14350d1b139000-4be0042179c25a454eba1a259d7cf3a7:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2008\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/b85a15d67a6803ff9db63dfe607cb6e3-e16568f1ca391e08d4a72d692f61860a:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2008\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/a4559b7d94476006d4bbca1cd32dd9cd-ddb0bf2ead3dc2a76244d7f11422928c:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2009\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/5cbc80d6089e704ddb5b96f9cf217ea7-70b64a5294643180273554a5093b5d7d:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2009\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/dd1141c0426ee4c59723806947479626-be6763cfa8aaf24625bf3a4fae0be83e:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2009\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/4aad13c6997f871fe3e74c8198ac3b76-1aa50368cb7c55085920bbd0120a71f1:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2010\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/e0f325300888135e13de1e1480971585-cabd065eeec0e4042a53d0ea76f8407c:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2010\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/27a93a189b6246f392cef16019fec0c1-d006c423a8651f08c319a54df02431d0:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2010\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/9deb1247a50eb05a36e937e1f22fd3e7-c29543b9705c0378a834e68e508f0bc7:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2011\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/480821e250c6498d0eb2785435084b16-24c768de536d6469705a6bbc7e5f1099:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2011\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/ea6304d8745c8ab0af248237c49d1a86-c13a93c740dc97a21eab88690f31a0ae:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2011\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/6ca6a05f865016b73b267e0270c3a3f9-ee303f7451d13a9ab05c989247df3cfa:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2012\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/62cd1f3ab1190b59b3ce5433b594563c-9231ba2e6a3fe441b6c3d4bf183cf0da:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2012\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/9ea1a07a2e4eb10bc7329a6b7712ad50-0008bd6c9e4ec599e235f18c58920d48:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2012\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/addf86502fd9be84571e10232edb5ed2-1e63d2384c4465335cd8e1d81f60dced:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2013\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/f4d2857a0aa1f3a7a58704ce2c01e9d6-bc0b507c95ba89297606cb8e523a80ab:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2013\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/e1a756fe7bc3b4fa5bea9d1c744a4a25-591d58bbfe3d5a9bb44ac554cfd7fef3:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2013\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/a40fa1c12f2363891dcbf31d3606561f-26cef1e33d9d142469ca0e7b64be57e7:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2014\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/a39bd35d847854132ddd2e2e4838be0d-6bf2bf76742a6ffd3456d952ddbbef5b:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2014\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/50b846d3051db5709b3d82638c66c4eb-56b1ad7a8caa566a811f5e6d2df1a72d:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2014\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/006d9bc595bd18bda3ac04c71c45594e-659cb2a465fb12093d3fd8a18967ffaf:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2015\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/4362d023159a489876bbba73f9e8bd6a-dd50cb4faeb904842488021d17bf6634:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2015\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/aef695018a6d954c379f39aacd033c81-38090be80bf234ab817762db07af5b85:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2015\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/93293446131ac962f5d8f08d851fa86a-e47c46cf1795769dfad57fb329838e94:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2016\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/c210c1c88d90f0b9d929c6e28a845d23-2fe3367d6fca5b830c1b6749eec37e48:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2016\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/d17754fbde2e1ab6993f6988f1c05219-981d06c5a662f14d6fa1545ce45444a7:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2016\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/77c519c647a3a7523dbc1d6464ccf766-9e8e5d9e518711326a1cb6a28545f7b7:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2017\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/b75f8bae580079ea8f61cd33016a91e9-6128e95712aa67b8dd479b846ef07192:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2017\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/1aeed70915d851f468dae86ff0eda2f0-901d344e42852da85c721cb1a0389b66:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2017\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/5a45a8a6933c23c418a66238c00849a9-dafd3739c747d642fb34490f87b3830e:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2018\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/3065ff0d1fcfdbba2bdd8d9b38ca2368-424523ef86e4995f5fb9bb6fb5abec88:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2018\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/5d56cb5ff3216c75da8942ce5472b910-09cb7f1bfb37e8a3fc5925b5993f05b8:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2018\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/4daf933fd8ecc175f29eee2127fd877d-76c1abfeac92c846d2776045b456fe93:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2019\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/d775e334c56658963df6f557b14a8bfa-fd09313f26f20f151573ccbb60739037:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2019\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/d88be0304c882bf79bf2376a3aa7db1f-7b7bc8318b2112b132788bea4c80305c:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2019\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/d4074269836e7b14f8cfd92955ca26e9-e921342ada8523d07b3615438d7365d6:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2020\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/dc3c53698d101e0b8cb8fe96eed6f5c6-ae7253b4fe3945069f5dd769950aa5b5:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2020\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/c8a4deda9ee8167a48d0b3746415f502-2719ad4d73e53d29dfce8f9ecf0d07f5:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2020\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/44f55031893c88f5643b51ff22444f62-63b776a8d5002e8b10dd77ae5813096c:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2021\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/e1255b24b14089ae0cd52d589625b5d0-cbaf2ef98225ae014c7140ee1bd600e4:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2021\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/7b18cf28dc7636d892913376b029e2ca-9f2c720584a2fedbeba002c60151534e:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2021\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/346b70409961a8ef71a911dc62e0bd94-645c844e4be2c5363da5ebd432bf8896:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2022\100m\landsat.tif
# Downloaded image for segment 1, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/0cee212cf90e5f288c96065a4e19efbf-37796b71059846832b0339b614b8fa99:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2022\200m\landsat.tif
# Downloaded image for segment 1, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/93a395e989c00965fc4a743a014ab73a-d7c4e094b39c659dc66bfd028495f984:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_1_2022\300m\landsat.tif
# Downloaded image for segment 1, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/20f1670c63da73e382ade95431734f52-2cde9e191a47ef154be8720aa10f20f5:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2007\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/3136df899c455917c1fe14933c7044e3-fae85b7a00e7a57f5c890a60b4bf7de1:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2007\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/72be641db5f298ac212c7534dc88f6a7-29f726309ae8e1b603112f14080206ba:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2007\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/ba372fec776cb9ca7ecac2a121b45c56-cfb9921e5a589e2be54baec3274a1bae:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2008\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/11880ebe6f59daa6a14e82f62d2d3791-7a763764d53a83418914989a62a73f1f:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2008\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/a8eebe69cab840f45db49e37296e4e0f-6a265f5d0a83a6ad55d3c1db92ab8412:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2008\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/667277dc17de17feea23e3a50f8bfcf1-1106f1e9f87d39894d2dfd345880d944:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2009\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/d67e0bb9fe3d08ab52f934466f943728-a846c4256ac4aa213fae01af9ba75cb3:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2009\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/cdfe80ae6e4ac0b1d72d9bd9b6c30539-d1a2d45283c287fc2090b976d13a1359:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2009\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/eaf853fc04e3c3e96a0c06fdc05a0a17-e78e4a00982ff75b7631ce53156fe2af:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2010\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/1490f5032aead36da1987b89fb3ff7fb-5571e50f1906680fae226f1368489b21:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2010\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/f00b8091d1529d224b0dfeefd8b82a0b-a5cda6f5f04211deb04cecdab61fcbbe:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2010\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/fbd9b30987f5cc8e4402be6cabedadf2-ae4b302657484ee2bbf41e23a24af88e:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2011\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/a9f5e5430e13dc64937954a964fef1cf-8a3370420af043200aadae72415684e8:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2011\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/9a77f2eba30631fcad5e153f99591f8f-19f12f11939c68923963dfed7a3b2655:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2011\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/91865da9499625a75a78d050272aed2a-1dce3a02f7404da0d099ed1adbc5bcad:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2012\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/0215245d82538bd183d434880099c8ef-e69f7d4e349d28e4b86cc12a0fbe72f0:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2012\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/039156de1e53694574f86196e6278f7e-f8eb098a18df633d5b22069f2381302a:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2012\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/a77b31be1ec3cac7672c10d9b3c315e1-c086f4cadb52a16547cdaf6c183dd5c2:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2013\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/4060c66f6e036f7089009b8f15e48eee-f3238fd0db3629454f48d2f1f1a0fc60:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2013\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/37e1eddd6ddf4ca509bb90dd9373921b-5223bde8bcc4bec9e81b63f6d6c20a1d:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2013\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/ecfa9bb49c90e32a986ef8291933fb45-90fa3e27811795a2e9cc3d8154e04a41:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2014\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/1ca0806b2a46cff682d2a039c68d7164-181c17d2c330782cb39243978be4572a:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2014\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/bb8a9a339b5709979f2ae0137d15713f-8edc23d7e72a7d3414b3617f896d30e7:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2014\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/6f5bae552aac99de3eccd34bddba4a37-bae799b561f9fd2f707be28fd49e96ee:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2015\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/1713a9c6e4d2acbb3ecb0b9b0854456e-3d83fdb53455aabbc9b56aa98b85eeb7:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2015\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/32edea958cf0b65cfc09c586ecaffea5-e4112d5832b751d2f60f3df3a05c03dd:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2015\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/a0f0b81e2b5d2c6ec3a45b000ec2db6f-1bc45dda4172862158b2830e3bdf91d4:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2016\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/607f7b1eca633137d389b41902af709b-547dcee98abf46f97676688371111ff5:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2016\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/6ee7829da5b398adde721e7417cd0715-c412ddebd14e6d04091b5bfff57e0000:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2016\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/f5974313e1a77e319deb5fbedee4812a-ccc5c9012f44fb3d9b7363ca2f9e4770:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2017\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/85aa6ec76d928b102fa8edb45019b6de-378375842a477d4fa88aa0b611f0c1e0:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2017\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/a4397aac31500b2f6706e8f29ea32d03-318f4ba094aec8089ef4aa74fd085084:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2017\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/97d2226d955386497adea89888424a96-910d2823d979a23d0d37a392e0a6487a:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2018\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/98b7ba508ce2e975699d2f80504cba0c-65c4f86401d276865f1168cc7233b10a:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2018\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/d5f62e1bed83674f3fa9a13936212092-8a99c738d103d80cfe023a677827b075:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2018\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/87a49825ce3a0cd67aa864d28faf9f3f-b9e1323a349b01d8d24cd3fe8908b912:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2019\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/cedb4ef0c36f0aa724792ee91b465115-7a14a18dbd539aec846c242892f821e9:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2019\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/2101d038d65a6a63eb36ae5152190fd0-d0a9cdac8c5e6f06e271485a2b78f1c3:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2019\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/980aea3bbd76cefa9b119499ede569f4-7740b0fd45cd54ea91af6e51f5996b74:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2020\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/84b78f354ffcf089b11a397194cf5a46-fbfaaffc3af1727e2f763027ff0fadce:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2020\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/d35c3b79c525bc5338ab81bb06b46c54-d7a29cefc8afabc6543f74ec36e6a7f7:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2020\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/cd98b0b093f33bcf5196ccebaec274ae-4124e2b5e31112a39ee0691c58e52990:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2021\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/6917971b0fdce9abcfb7e6a7b641973b-9dc0d20aeae706bf90628a9a3db62553:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2021\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/7abda12e81f513d542fba49c56c11a08-e0eb75948a279e28a487d2be60b054be:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2021\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/e4ee6ab004745755bddd7c38032baf84-216d8687527239bb52761f7886c6935c:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2022\100m\landsat.tif
# Downloaded image for segment 2, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/b8b1ea6fd731611af488333562b76de0-95157595bb62d4439e9d8e12a52c2d66:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2022\200m\landsat.tif
# Downloaded image for segment 2, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/2cf87542d0d181ca55d2dc1a4e2d4174-3de6c0afa2cdffb25a8eb4215542e1a0:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_2_2022\300m\landsat.tif
# Downloaded image for segment 2, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/6cb5c43c331157b64f31e30f6824c384-f99a243ad2254b44de54734323fe943e:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2007\100m\landsat.tif
# Downloaded image for segment 3, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/8718f430e40b8ad86bc1a1fb63b84d2d-15c298a34ee0901d7f3d673a66adf5e0:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2007\200m\landsat.tif
# Downloaded image for segment 3, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/9238f7234e62de12553032cd5a333e92-d8da5ba1d2ef0e6641fa4431779e2f8d:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2007\300m\landsat.tif
# Downloaded image for segment 3, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/b95f8710c24ccd774db38a62db1d749b-60d8788f9762e5c24f70699885d70948:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2008\100m\landsat.tif
# Downloaded image for segment 3, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/c948fa4f3096132ae27ee1d55947072a-d16bdfefd8ab1fc9bae2ace1ff305a95:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2008\200m\landsat.tif
# Downloaded image for segment 3, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/068f5589ea4f71de9b59a715c54be165-49ef22c2eb8e8aea0989c51d2e5d4825:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2008\300m\landsat.tif
# Downloaded image for segment 3, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/3dd4eb614569f9b5c04fdab9f77a8fb3-10fc2670360d3888889fd6ef59e39d72:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2009\100m\landsat.tif
# Downloaded image for segment 3, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/d1334570a2412b417e20a55422766e4f-67d2144f4f9cb93a8b991555faa918c8:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2009\200m\landsat.tif
# Downloaded image for segment 3, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/67945ed6b7642602b73f9dca9052da58-618d24d0bb145eb35f905ab16d1a3c1d:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2009\300m\landsat.tif
# Downloaded image for segment 3, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/b5a7d8f6a4d9ee579927bd8718bb2313-f9feb2fe52cfc9a1c6579ddcbc08f84a:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2010\100m\landsat.tif
# Downloaded image for segment 3, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/56ee2b8bd473c6b095135e92d9110f30-7f9d04d49c7fbb911595ab23f6324dc6:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2010\200m\landsat.tif
# Downloaded image for segment 3, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/d411e686b2f42593224a29ae95c1ea6a-89fe402bbcf14c00614096295246a1e6:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2010\300m\landsat.tif
# Downloaded image for segment 3, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/d7152453a6ceee95b1c555cebe534e71-38dddf8a7ffb59bfab430060ff09628c:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2011\100m\landsat.tif
# Downloaded image for segment 3, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/ed8627a04112f6552a752b4fc65a2ac9-8d730ff08a19632ff1682307c05a55b0:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2011\200m\landsat.tif
# Downloaded image for segment 3, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/aeb02d8a69cc1db92a7ab376af24256a-4388186cc884b00b2b259b2ecf7650da:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2011\300m\landsat.tif
# Downloaded image for segment 3, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/774f28a768fe22ea16db61738c3cc632-2f01c1158f00559d7315591fc8c81ec9:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2012\100m\landsat.tif
# Downloaded image for segment 3, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/73dffe506903d1a3c2b645009dbf4753-08b3b45ff2143c4601884184121e7a8e:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2012\200m\landsat.tif
# Downloaded image for segment 3, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/1dee75cecc7f96ef370f163a956b9903-4e5ed5cfb3bddd48d30899ca950a030a:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2012\300m\landsat.tif
# Downloaded image for segment 3, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/8a10f575e0841036d689a997ca75d041-7f212b61be5df85703d28f3928f4a5c6:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2013\100m\landsat.tif
# Downloaded image for segment 3, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/a67ebaabfed05596e6f007df9a069f3f-6fc498fc291cc7574ff3b29d4752da0b:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2013\200m\landsat.tif
# Downloaded image for segment 3, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/86a2f231f22364053893978417dfec21-355783ba79ef74634da476372335804c:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2013\300m\landsat.tif
# Downloaded image for segment 3, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/bf34b9a110f9f1df8676d5e8476bf652-ee5b751bd326e8e15ace0f8738d890da:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2014\100m\landsat.tif
# Downloaded image for segment 3, 100m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/2434e84fcd2a32ecf541f6f9f964cea2-93858c1389804a21d134c8ed9dc21f71:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2014\200m\landsat.tif
# Downloaded image for segment 3, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/25099ad079c4a76de83d8b643e3a8e97-a4c80592fa49fe6956e55ce9d434fac8:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (100m aggregation)\segment_3_2014\300m\landsat.tif
# Downloaded image for segment 3, 300m buffer
# Generating URL ...
# ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2009\300m\landsat.tif
# Downloaded image for segment 25, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/25b18254f794a8949578979c48a222e7-74ab089104882fdac0bc2f284927c003:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2009\400m\landsat.tif
# Downloaded image for segment 25, 400m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/d9c35f6e23ff0090dc70959993e3bf09-da359e247db4c37662a4f0f1a6f16059:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2010\200m\landsat.tif
# Downloaded image for segment 25, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/d4181fd639f4c7fedbabf80e1628ebb9-e5f8d147a8d35724c9233cdf7fa9852e:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2010\300m\landsat.tif
# Downloaded image for segment 25, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/d0f570df7d18074731509bceb5aa00e8-203a31bfa13dca0ef9058bd98af29f95:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2010\400m\landsat.tif
# Downloaded image for segment 25, 400m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/4e56d523130538a4783f1b028205d365-c24fb23b19e4581b0d7a98245166e0f0:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2011\200m\landsat.tif
# Downloaded image for segment 25, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/2132e7f2e82eb953ad9e8ba303e099e8-55d9e28403dacae7581f180482732254:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2011\300m\landsat.tif
# Downloaded image for segment 25, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/8af7f3812cd39299077de7ec8bdf16f2-bffaf68b40d9841cd9db5124dea5fc88:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2011\400m\landsat.tif
# Downloaded image for segment 25, 400m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/7a53627cd5893e958a5610fb8e486e67-c82a9e07481a0098b05c6304690d6a9d:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2012\200m\landsat.tif
# Downloaded image for segment 25, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/69c927251426c7c53f9bfb6c20a15c48-61edf85b86cc33bd12508caa1c05bb7e:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2012\300m\landsat.tif
# Downloaded image for segment 25, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/3f7c60f2848c40112b2b0eba1854eb24-348798f10149702ae0764d2ff28a528e:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2012\400m\landsat.tif
# Downloaded image for segment 25, 400m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/cc7624b3d99d7278f64b91be6e9f68c9-ca5f141761de59670453df48431cf5d5:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2013\200m\landsat.tif
# Downloaded image for segment 25, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/588ba67f93e77ea6f27a8fe191ada2b0-7a339e50f0daddddaea9e0191dab12fe:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2013\300m\landsat.tif
# Downloaded image for segment 25, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/69900dc2fbe73ba9cad451f5bb129fd9-a54afe12cb93172d0e5434afaa50192b:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2013\400m\landsat.tif
# Downloaded image for segment 25, 400m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/96a2b0c46388d80c5a366d421ed63ae2-b507fe180c6088447824fc2433a5c3a5:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2014\200m\landsat.tif
# Downloaded image for segment 25, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/dfa8e7237ab8267c16e63d12c5953497-aa3784819e954bf766881f698f8ab15f:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2014\300m\landsat.tif
# Downloaded image for segment 25, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/b34db131f058c6afd4183b240bfb47ec-54d76cecf6cf6a4592b6b857936adf54:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2014\400m\landsat.tif
# Downloaded image for segment 25, 400m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/e218021c8deacc669844fcf26369c6c9-e52f51345fc4c3da64e84e3803bae6cc:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2015\200m\landsat.tif
# Downloaded image for segment 25, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/3322b3720dece73f33cf4c75cb23d688-80bec0c2f5eb53f2afb297274fb36daa:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2015\300m\landsat.tif
# Downloaded image for segment 25, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/c17d5a37631d8d63b652086d5ba736e6-6f4eee215e3d18bd5bcf29421cfecf1e:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2015\400m\landsat.tif
# Downloaded image for segment 25, 400m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/a514760b539e9ed0f99a5e6d5e4fefd9-7f71ef9992a2a5121a8076c6834f3bb5:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2016\200m\landsat.tif
# Downloaded image for segment 25, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/9100c0023e2748e9e3a6c3441486aeed-a6a27fde129495465a9f6a5a56ac2a5c:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2016\300m\landsat.tif
# Downloaded image for segment 25, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/486e34ace02b59f0471ff7abbbd713c6-31c2e48ae8f857f72471756212bb5286:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2016\400m\landsat.tif
# Downloaded image for segment 25, 400m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/50fdcef4bfc69416578e8314b7c615f6-95b6319e57a12d9764ab55aed1b0ccc1:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2017\200m\landsat.tif
# Downloaded image for segment 25, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/62dce317ae0019fc0e77a1a9642ddecf-5f65b5ce38facdf6f89f70d98cb94ffb:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2017\300m\landsat.tif
# Downloaded image for segment 25, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/6a13e57dc40ce92c445d5a8560fd271b-176756add0d531e9b86e514c2a89f2ce:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2017\400m\landsat.tif
# Downloaded image for segment 25, 400m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/67a0d94ad10c080f19cee3a7b043cfd4-c9e5261e43ff4f1ff0ac837d53510884:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2018\200m\landsat.tif
# Downloaded image for segment 25, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/85e82a5fa914d86e9ffae4f8a2203d27-134535815adadcb4ae37b9e3ef9458d7:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2018\300m\landsat.tif
# Downloaded image for segment 25, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/32121c50274914b83649ddcafd133fd7-a036a975cfa6a2653a2f8b8c22b079e9:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2018\400m\landsat.tif
# Downloaded image for segment 25, 400m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/e9efb84a4bca85f9173d24ef588c4151-54441b5f85a51da1f8f111482844bfb2:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2019\200m\landsat.tif
# Downloaded image for segment 25, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/f461485ea647adfcf0b0296836ddbbf1-de303c77170ef49040569fe8598abd4e:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2019\300m\landsat.tif
# Downloaded image for segment 25, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/85b28a232aeb83ef5ea77c8eddee35e1-e6f196e262121c36d49e6fec72ab6bcd:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2019\400m\landsat.tif
# Downloaded image for segment 25, 400m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/5f4a51dc177ed354a3ad70e9da5f7f56-a891b5a2e7b06bd4b898140f841000a8:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2020\200m\landsat.tif
# Downloaded image for segment 25, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/7206aa7f7be3ac3c9451a371f57951c6-7767e8678a9e03aa307853ce28631e11:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2020\300m\landsat.tif
# Downloaded image for segment 25, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/a05454063f60e436ec1df804190f4e7f-2234014e8db781365cc8f96715d06e9c:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2020\400m\landsat.tif
# Downloaded image for segment 25, 400m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/857f365e5d1136a80ced3f3ffaf829d4-45d37bdf0028d16de102cbc8b3b460e1:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2021\200m\landsat.tif
# Downloaded image for segment 25, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/a14a4bf82c8cf8c64ab7c56eb22c5164-78f7970882e64a6016d68fd6544e2569:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2021\300m\landsat.tif
# Downloaded image for segment 25, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/2d6344c8dffefd0ba490383537157620-81c34eccba3f9bec7b124584e31efcb7:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2021\400m\landsat.tif
# Downloaded image for segment 25, 400m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/0d0682f2cca2a8b0c5d46dab57a0b610-9dfb19971f1bd9c42dd6ae8e03eaf566:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2022\200m\landsat.tif
# Downloaded image for segment 25, 200m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/5df610cd0916c39957012f7649ea4d71-9461a3f474b9ffaabaa7eba229224b85:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2022\300m\landsat.tif
# Downloaded image for segment 25, 300m buffer
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/149715335715/thumbnails/9e70ee70be618f73a81bd16197c2973a-dc87978018ca8689d0b5c74532772699:getPixels
# Please wait ...
# Data downloaded to C:\Users\gmoor\Documents\REVISED CAPSTONE PROJECT\Data\First 6000 segments (200m aggregation)\segment_25_2022\400m\landsat.tif
# Downloaded image for segment 25, 400m buffer
