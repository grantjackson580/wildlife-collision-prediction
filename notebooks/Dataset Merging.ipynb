# %%
import pandas as pd
import numpy as np
import os

features_df = pd.read_csv('C:\\Users\\gmoor\\Documents\\REVISED CAPSTONE PROJECT\\Data\\new_sprectal_indices.csv')

# %%
features_df
# Out:
#      segment_type  segment_id  year  buffer_size sensor_type  ndvi_mean  \
# 0            100m           1  2007          100          L7   0.137357
# 1            100m           1  2007          200          L7   0.140460
# 2            100m           1  2007          300          L7   0.139994
# 3            100m           1  2008          100          L7   0.089838
# 4            100m           1  2008          200          L7   0.093755
# ...           ...         ...   ...          ...         ...        ...
# 3099         200m          25  2021          300          L8   0.371926
# 3100         200m          25  2021          400          L8   0.405604
# 3101         200m          25  2022          200          L8   0.316048
# 3102         200m          25  2022          300          L8   0.384971
# 3103         200m          25  2022          400          L8   0.422370
#
#       ndvi_std  ndwi_mean  ndwi_std  ndbi_mean  ndbi_std     ndvi_category  \
# ...

# %%
onehundred_features_df = features_df[features_df['segment_type'] == '100m']

onehundred_features_df
# Out:
#      segment_type  segment_id  year  buffer_size sensor_type  ndvi_mean  \
# 0            100m           1  2007          100          L7   0.137357
# 1            100m           1  2007          200          L7   0.140460
# 2            100m           1  2007          300          L7   0.139994
# 3            100m           1  2008          100          L7   0.089838
# 4            100m           1  2008          200          L7   0.093755
# ...           ...         ...   ...          ...         ...        ...
# 2532         100m          50  2021          200          L8   0.304474
# 2533         100m          50  2021          300          L8   0.363243
# 2534         100m          50  2022          100          L8   0.284520
# 2535         100m          50  2022          200          L8   0.307270
# 2536         100m          50  2022          300          L8   0.374419
#
#       ndvi_std  ndwi_mean  ndwi_std  ndbi_mean  ndbi_std     ndvi_category  \
# ...

# %%
import geopandas as gpd

onehundred_segment_gdf = gpd.read_file('C:\\Users\\gmoor\\Documents\\REVISED CAPSTONE PROJECT\\Data\\first200_aggregate_segments (100meters).gpkg')

# %%
onehundred_segment_gdf
# Out:
#     segment_id  100m_segment_id  Year  roadkill_count  min_dist_1  min_dist_2  \
# 0          1-4                1  2007             0.0  142.830604         NaN
# 1          1-4                1  2008             0.0  142.830604         NaN
# 2          1-4                1  2009             0.0  142.830604         NaN
# 3          1-4                1  2010             0.0   97.733578  142.830604
# 4          1-4                1  2011             0.0   23.246441   97.733578
# ..         ...              ...   ...             ...         ...         ...
# 731    197-200               50  2018             0.0    7.767510   15.166746
# 732    197-200               50  2019             0.0    7.767510   15.166746
# 733    197-200               50  2020             0.0    7.767510   15.166746
# 734    197-200               50  2021             0.0    7.767510   15.166746
# 735    197-200               50  2022             0.0    7.767510   15.166746
#
# ...

# %%
# Create duplicates with different buffer sizes
buffer_sizes = [100, 200, 300]
duplicated_dfs = []

for buffer_size in buffer_sizes:
    temp_df = onehundred_segment_gdf.copy()
    temp_df['buffer_size'] = buffer_size
    duplicated_dfs.append(temp_df)

# Concatenate all the duplicated dataframes
duplicated_onehundred_segment_gdf = pd.concat(duplicated_dfs, ignore_index=True)

# %%
duplicated_onehundred_segment_gdf[(duplicated_onehundred_segment_gdf['Year'] == 2014) & (duplicated_onehundred_segment_gdf['100m_segment_id'] == 1)]
# Out:
#      segment_id  100m_segment_id  Year  roadkill_count  min_dist_1  \
# 7           1-4                1  2014             0.0   23.246441
# 743         1-4                1  2014             0.0   23.246441
# 1479        1-4                1  2014             0.0   23.246441
#
#       min_dist_2  min_dist_3  \
# 7      97.733578  142.830604
# 743    97.733578  142.830604
# 1479   97.733578  142.830604
#
#                                                geometry  buffer_size
# 7     LINESTRING (240608.083 4277443.023, 240572.762...          100
# 743   LINESTRING (240608.083 4277443.023, 240572.762...          200
# 1479  LINESTRING (240608.083 4277443.023, 240572.762...          300

# %%
onehundred_segment_combined_df = pd.merge(
    duplicated_onehundred_segment_gdf,
    onehundred_features_df,
    left_on=['100m_segment_id', 'Year', 'buffer_size'],
    right_on=['segment_id', 'year', 'buffer_size']
)

onehundred_segment_combined_df.head()
# Out:
#   segment_id_x  100m_segment_id  Year  roadkill_count  min_dist_1  min_dist_2  \
# 0          1-4                1  2007             0.0  142.830604         NaN
# 1          1-4                1  2008             0.0  142.830604         NaN
# 2          1-4                1  2009             0.0  142.830604         NaN
# 3          1-4                1  2010             0.0   97.733578  142.830604
# 4          1-4                1  2011             0.0   23.246441   97.733578
#
#    min_dist_3                                           geometry  buffer_size  \
# 0         NaN  LINESTRING (240608.083 4277443.023, 240572.762...          100
# 1         NaN  LINESTRING (240608.083 4277443.023, 240572.762...          100
# 2         NaN  LINESTRING (240608.083 4277443.023, 240572.762...          100
# 3         NaN  LINESTRING (240608.083 4277443.023, 240572.762...          100
# 4  142.830604  LINESTRING (240608.083 4277443.023, 240572.762...          100
#
# ...

# %%
onehundred_segment_combined_df.describe()
# Out:
#        100m_segment_id         Year  roadkill_count   min_dist_1   min_dist_2  \
# count      2132.000000  2132.000000     2132.000000  2132.000000  1793.000000
# mean         26.193246  2014.694653        0.001407    33.107940    52.521209
# std          14.475345     4.573002        0.037494    21.204567    45.051157
# min           1.000000  2007.000000        0.000000     7.230170    15.166746
# 25%          15.000000  2011.000000        0.000000    15.474269    16.684059
# 50%          26.000000  2015.000000        0.000000    43.397915    46.782964
# 75%          38.000000  2019.000000        0.000000    43.461173    47.126394
# max          50.000000  2022.000000        1.000000   142.830604   205.658027
#
#         min_dist_3  buffer_size  segment_id_y         year    ndvi_mean  \
# count  1655.000000  2132.000000   2132.000000  2132.000000  2132.000000
# mean     57.609353   200.046904     26.193246  2014.694653     0.217603
# ...

# %%
onehundred_segment_combined_df[(onehundred_segment_combined_df['Year'] == 2014) & (onehundred_segment_combined_df['100m_segment_id'] == 1)]
# Out:
#      segment_id_x  100m_segment_id  Year  roadkill_count  min_dist_1  \
# 7             1-4                1  2014             0.0   23.246441
# 717           1-4                1  2014             0.0   23.246441
# 1428          1-4                1  2014             0.0   23.246441
#
#       min_dist_2  min_dist_3  \
# 7      97.733578  142.830604
# 717    97.733578  142.830604
# 1428   97.733578  142.830604
#
#                                                geometry  buffer_size  \
# 7     LINESTRING (240608.083 4277443.023, 240572.762...          100
# 717   LINESTRING (240608.083 4277443.023, 240572.762...          200
# 1428  LINESTRING (240608.083 4277443.023, 240572.762...          300
#
#      segment_type  ...  sensor_type  ndvi_mean  ndvi_std  ndwi_mean  ndwi_std  \
# 7            100m  ...           L8   0.273896  0.164199  -0.332985  0.142192
# 717          100m  ...           L8   0.272314  0.151866  -0.343256  0.130502
# ...

# %%
twohundred_features_df = features_df[features_df['segment_type'] == '200m']

twohundred_features_df
# Out:
#      segment_type  segment_id  year  buffer_size sensor_type  ndvi_mean  \
# 890          200m           1  2007          200          L7   0.144580
# 891          200m           1  2007          300          L7   0.136496
# 892          200m           1  2007          400          L7   0.129165
# 893          200m           1  2008          200          L7   0.095888
# 894          200m           1  2008          300          L7   0.090837
# ...           ...         ...   ...          ...         ...        ...
# 3099         200m          25  2021          300          L8   0.371926
# 3100         200m          25  2021          400          L8   0.405604
# 3101         200m          25  2022          200          L8   0.316048
# 3102         200m          25  2022          300          L8   0.384971
# 3103         200m          25  2022          400          L8   0.422370
#
#       ndvi_std  ndwi_mean  ndwi_std  ndbi_mean  ndbi_std     ndvi_category  \
# ...

# %%
import geopandas as gpd

twohundred_segment_gdf = gpd.read_file('C:\\Users\\gmoor\\Documents\\REVISED CAPSTONE PROJECT\\Data\\first80_aggregate_segments (200meters).gpkg')

# %%
twohundred_segment_gdf
# Out:
#     segment_id  200m_segment_id  Year  roadkill_count  min_dist_1  min_dist_2  \
# 0          1-8                1  2007             0.0  142.823867         NaN
# 1          1-8                1  2008             0.0  142.823867         NaN
# 2          1-8                1  2009             0.0  142.823867         NaN
# 3          1-8                1  2010             0.0   97.762742  142.823867
# 4          1-8                1  2011             0.0   23.277344   97.762742
# ..         ...              ...   ...             ...         ...         ...
# 107      73-80               10  2018             0.0   43.412906   47.037893
# 108      73-80               10  2019             0.0   43.412906   47.037893
# 109      73-80               10  2020             0.0   43.412906   47.037893
# 110      73-80               10  2021             0.0   43.412906   47.037893
# 111      73-80               10  2022             0.0   43.412906   47.037893
#
# ...

# %%
# Create duplicates with different buffer sizes
buffer_sizes = [200, 300, 400]
duplicated_dfs = []

for buffer_size in buffer_sizes:
    temp_df = twohundred_segment_gdf.copy()
    temp_df['buffer_size'] = buffer_size
    duplicated_dfs.append(temp_df)

# Concatenate all the duplicated dataframes
duplicated_twohundred_segment_gdf = pd.concat(duplicated_dfs, ignore_index=True)

# %%
duplicated_twohundred_segment_gdf[(duplicated_twohundred_segment_gdf['Year'] == 2007) & (duplicated_twohundred_segment_gdf['200m_segment_id'] == 1)]
# Out:
#     segment_id  200m_segment_id  Year  roadkill_count  min_dist_1  min_dist_2  \
# 0          1-8                1  2007             0.0  142.823867         NaN
# 112        1-8                1  2007             0.0  142.823867         NaN
# 224        1-8                1  2007             0.0  142.823867         NaN
#
#      min_dist_3                                           geometry  \
# 0           NaN  LINESTRING (240608.083 4277443.023, 240538.644...
# 112         NaN  LINESTRING (240608.083 4277443.023, 240538.644...
# 224         NaN  LINESTRING (240608.083 4277443.023, 240538.644...
#
#      buffer_size
# 0            200
# 112          300
# 224          400

# %%
twohundred_segment_combined_df = pd.merge(
    duplicated_twohundred_segment_gdf,
    twohundred_features_df,
    left_on=['200m_segment_id', 'Year', 'buffer_size'],
    right_on=['segment_id', 'year', 'buffer_size']
)

twohundred_segment_combined_df.head()
# Out:
#   segment_id_x  200m_segment_id  Year  roadkill_count  min_dist_1  min_dist_2  \
# 0          1-8                1  2007             0.0  142.823867         NaN
# 1          1-8                1  2008             0.0  142.823867         NaN
# 2          1-8                1  2009             0.0  142.823867         NaN
# 3          1-8                1  2010             0.0   97.762742  142.823867
# 4          1-8                1  2011             0.0   23.277344   97.762742
#
#    min_dist_3                                           geometry  buffer_size  \
# 0         NaN  LINESTRING (240608.083 4277443.023, 240538.644...          200
# 1         NaN  LINESTRING (240608.083 4277443.023, 240538.644...          200
# 2         NaN  LINESTRING (240608.083 4277443.023, 240538.644...          200
# 3         NaN  LINESTRING (240608.083 4277443.023, 240538.644...          200
# 4  142.823867  LINESTRING (240608.083 4277443.023, 240538.644...          200
#
# ...

# %%
twohundred_segment_combined_df.describe()
# Out:
#        200m_segment_id         Year  roadkill_count  min_dist_1  min_dist_2  \
# count       327.000000   327.000000      327.000000  327.000000  273.000000
# mean          5.623853  2014.651376        0.009174   39.044995   64.188518
# std           3.238350     4.587345        0.095488   28.967242   44.560548
# min           1.000000  2007.000000        0.000000   13.668233   15.698211
# 25%           2.000000  2011.000000        0.000000   23.277344   37.610101
# 50%           6.000000  2015.000000        0.000000   37.851428   47.108751
# 75%           9.000000  2019.000000        0.000000   43.425417   96.768087
# max          10.000000  2022.000000        1.000000  142.823867  205.433000
#
#        min_dist_3  buffer_size  segment_id_y         year   ndvi_mean  \
# count  252.000000   327.000000    327.000000   327.000000  327.000000
# mean    70.937429   300.000000      5.623853  2014.651376    0.242964
# std     46.893437    81.774792      3.238350     4.587345    0.136683
# ...

# %%
twohundred_segment_combined_df[(twohundred_segment_combined_df['Year'] == 2014) & (twohundred_segment_combined_df['200m_segment_id'] == 1)]
# Out:
#     segment_id_x  200m_segment_id  Year  roadkill_count  min_dist_1  \
# 7            1-8                1  2014             0.0   23.277344
# 116          1-8                1  2014             0.0   23.277344
# 225          1-8                1  2014             0.0   23.277344
#
#      min_dist_2  min_dist_3  \
# 7     97.762742  142.823867
# 116   97.762742  142.823867
# 225   97.762742  142.823867
#
#                                               geometry  buffer_size  \
# 7    LINESTRING (240608.083 4277443.023, 240538.644...          200
# 116  LINESTRING (240608.083 4277443.023, 240538.644...          300
# 225  LINESTRING (240608.083 4277443.023, 240538.644...          400
#
#     segment_type  ...  sensor_type  ndvi_mean  ndvi_std  ndwi_mean  ndwi_std  \
# 7           200m  ...           L8   0.279916  0.145667  -0.347670  0.125840
# 116         200m  ...           L8   0.260406  0.150407  -0.326137  0.133125
# ...

# %%
total_segment_combined_df = pd.concat([onehundred_segment_combined_df, twohundred_segment_combined_df], ignore_index=True)

total_segment_combined_df.head()
# Out:
#   segment_id_x  100m_segment_id  Year  roadkill_count  min_dist_1  min_dist_2  \
# 0          1-4              1.0  2007             0.0  142.830604         NaN
# 1          1-4              1.0  2008             0.0  142.830604         NaN
# 2          1-4              1.0  2009             0.0  142.830604         NaN
# 3          1-4              1.0  2010             0.0   97.733578  142.830604
# 4          1-4              1.0  2011             0.0   23.246441   97.733578
#
#    min_dist_3                                           geometry  buffer_size  \
# 0         NaN  LINESTRING (240608.083 4277443.023, 240572.762...          100
# 1         NaN  LINESTRING (240608.083 4277443.023, 240572.762...          100
# 2         NaN  LINESTRING (240608.083 4277443.023, 240572.762...          100
# 3         NaN  LINESTRING (240608.083 4277443.023, 240572.762...          100
# 4  142.830604  LINESTRING (240608.083 4277443.023, 240572.762...          100
#
# ...

# %%
total_segment_combined_df.to_csv('first200_final_output_nonormalization_REVISED.csv', index=False, date_format=None)

# %%
total_segment_combined_df.to_excel('first80_final_output_nonormalization.xlsx', index=False)
